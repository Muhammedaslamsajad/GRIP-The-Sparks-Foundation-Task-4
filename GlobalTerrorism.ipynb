# %% [markdown]
# # Task-4 Exploratory Data Analysis on Global Terrorism
#
# ## Objective:
#
# #### * As a security/defence analyst, try to find out the hot zone of terrorism.
# #### * What all security issues and insights you can derive by EDA?

# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv(r"C:\Users\Lenovo\Documents\Data Science\python 3\projects\Grip\globalterrorism.csv", encoding = "ISO-8859-1")
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
data.shape
# Out:
# (181691, 135)

# %%
data
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
#dropping 
data=data.drop(['extended'],1)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_11692/247307011.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data=data.drop(['extended'],1)

# %%
data.shape
# Out:
# (181691, 134)

# %%
data
# Out:
#              eventid  iyear  imonth  iday approxdate resolution  country  \
# 0       197000000001   1970       7     2        NaN        NaN       58
# 1       197000000002   1970       0     0        NaN        NaN      130
# 2       197001000001   1970       1     0        NaN        NaN      160
# 3       197001000002   1970       1     0        NaN        NaN       78
# 4       197001000003   1970       1     0        NaN        NaN      101
# ...              ...    ...     ...   ...        ...        ...      ...
# 181686  201712310022   2017      12    31        NaN        NaN      182
# 181687  201712310029   2017      12    31        NaN        NaN      200
# 181688  201712310030   2017      12    31        NaN        NaN      160
# 181689  201712310031   2017      12    31        NaN        NaN       92
# 181690  201712310032   2017      12    31        NaN        NaN      160
#
#                country_txt  region                   region_txt  ... addnotes  \
# ...

# %%
#dropping 
data=data.drop(['nwoundus'],1)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_11692/3486741012.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data=data.drop(['nwoundus'],1)

# %%
data
# Out:
#              eventid  iyear  imonth  iday approxdate resolution  country  \
# 0       197000000001   1970       7     2        NaN        NaN       58
# 1       197000000002   1970       0     0        NaN        NaN      130
# 2       197001000001   1970       1     0        NaN        NaN      160
# 3       197001000002   1970       1     0        NaN        NaN       78
# 4       197001000003   1970       1     0        NaN        NaN      101
# ...              ...    ...     ...   ...        ...        ...      ...
# 181686  201712310022   2017      12    31        NaN        NaN      182
# 181687  201712310029   2017      12    31        NaN        NaN      200
# 181688  201712310030   2017      12    31        NaN        NaN      160
# 181689  201712310031   2017      12    31        NaN        NaN       92
# 181690  201712310032   2017      12    31        NaN        NaN      160
#
#                country_txt  region                   region_txt  ... addnotes  \
# ...

# %%
#dropping 
data=data.drop(['nwound'],1)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_11692/2011955874.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data=data.drop(['nwound'],1)

# %%
data
# Out:
#              eventid  iyear  imonth  iday approxdate resolution  country  \
# 0       197000000001   1970       7     2        NaN        NaN       58
# 1       197000000002   1970       0     0        NaN        NaN      130
# 2       197001000001   1970       1     0        NaN        NaN      160
# 3       197001000002   1970       1     0        NaN        NaN       78
# 4       197001000003   1970       1     0        NaN        NaN      101
# ...              ...    ...     ...   ...        ...        ...      ...
# 181686  201712310022   2017      12    31        NaN        NaN      182
# 181687  201712310029   2017      12    31        NaN        NaN      200
# 181688  201712310030   2017      12    31        NaN        NaN      160
# 181689  201712310031   2017      12    31        NaN        NaN       92
# 181690  201712310032   2017      12    31        NaN        NaN      160
#
#                country_txt  region                   region_txt  ... addnotes  \
# ...

# %%
#dropping 
data=data.drop(['nwoundte'],1)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_11692/3910327141.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data=data.drop(['nwoundte'],1)

# %%
data
# Out:
#              eventid  iyear  imonth  iday approxdate resolution  country  \
# 0       197000000001   1970       7     2        NaN        NaN       58
# 1       197000000002   1970       0     0        NaN        NaN      130
# 2       197001000001   1970       1     0        NaN        NaN      160
# 3       197001000002   1970       1     0        NaN        NaN       78
# 4       197001000003   1970       1     0        NaN        NaN      101
# ...              ...    ...     ...   ...        ...        ...      ...
# 181686  201712310022   2017      12    31        NaN        NaN      182
# 181687  201712310029   2017      12    31        NaN        NaN      200
# 181688  201712310030   2017      12    31        NaN        NaN      160
# 181689  201712310031   2017      12    31        NaN        NaN       92
# 181690  201712310032   2017      12    31        NaN        NaN      160
#
#                country_txt  region                   region_txt  ... addnotes  \
# ...

# %%
#dropping 
data=data.drop(['nkillus'],1)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_11692/1616472563.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data=data.drop(['nkillus'],1)

# %%
data
# Out:
#              eventid  iyear  imonth  iday approxdate resolution  country  \
# 0       197000000001   1970       7     2        NaN        NaN       58
# 1       197000000002   1970       0     0        NaN        NaN      130
# 2       197001000001   1970       1     0        NaN        NaN      160
# 3       197001000002   1970       1     0        NaN        NaN       78
# 4       197001000003   1970       1     0        NaN        NaN      101
# ...              ...    ...     ...   ...        ...        ...      ...
# 181686  201712310022   2017      12    31        NaN        NaN      182
# 181687  201712310029   2017      12    31        NaN        NaN      200
# 181688  201712310030   2017      12    31        NaN        NaN      160
# 181689  201712310031   2017      12    31        NaN        NaN       92
# 181690  201712310032   2017      12    31        NaN        NaN      160
#
#                country_txt  region                   region_txt  ... addnotes  \
# ...

# %%
#dropping 
data=data.drop(['nkillter'],1)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_11692/1627000261.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data=data.drop(['nkillter'],1)

# %%
data
# Out:
#              eventid  iyear  imonth  iday approxdate resolution  country  \
# 0       197000000001   1970       7     2        NaN        NaN       58
# 1       197000000002   1970       0     0        NaN        NaN      130
# 2       197001000001   1970       1     0        NaN        NaN      160
# 3       197001000002   1970       1     0        NaN        NaN       78
# 4       197001000003   1970       1     0        NaN        NaN      101
# ...              ...    ...     ...   ...        ...        ...      ...
# 181686  201712310022   2017      12    31        NaN        NaN      182
# 181687  201712310029   2017      12    31        NaN        NaN      200
# 181688  201712310030   2017      12    31        NaN        NaN      160
# 181689  201712310031   2017      12    31        NaN        NaN       92
# 181690  201712310032   2017      12    31        NaN        NaN      160
#
#                country_txt  region                   region_txt  ... addnotes  \
# ...

# %%
#dropping 
data=data.drop(['ishostkid'],1)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_11692/1125607630.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data=data.drop(['ishostkid'],1)

# %%
data
# Out:
#              eventid  iyear  imonth  iday approxdate resolution  country  \
# 0       197000000001   1970       7     2        NaN        NaN       58
# 1       197000000002   1970       0     0        NaN        NaN      130
# 2       197001000001   1970       1     0        NaN        NaN      160
# 3       197001000002   1970       1     0        NaN        NaN       78
# 4       197001000003   1970       1     0        NaN        NaN      101
# ...              ...    ...     ...   ...        ...        ...      ...
# 181686  201712310022   2017      12    31        NaN        NaN      182
# 181687  201712310029   2017      12    31        NaN        NaN      200
# 181688  201712310030   2017      12    31        NaN        NaN      160
# 181689  201712310031   2017      12    31        NaN        NaN       92
# 181690  201712310032   2017      12    31        NaN        NaN      160
#
#                country_txt  region                   region_txt  ... addnotes  \
# ...

# %%
#dropping 
data=data.drop(['nkill'],1)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_11692/885127455.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data=data.drop(['nkill'],1)

# %%
pd.set_option('display.max_columns',None)

# %%
data

# %%
data.shape
# Out:
# (181691, 127)

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'resolution',
#        'country', 'country_txt', 'region', 'region_txt',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=127)

# %% [markdown]
# ## Which type of Attack is most used by Terrorist group

# %%
plt.figure(figsize=(15,5))
s1=sns.countplot(data.attacktype1_txt)
s1.set_xticklabels(s1.get_xticklabels(),rotation=90)
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### In this graph, let's go through with different types of attack.
# ##### we can see that Bombing/Explosion is the highest number of attack type happened also Armed Assault

# %% [markdown]
# ### Let's check the most Target of Terrorism

# %%
plt.figure(figsize=(15,5))
s1=sns.countplot(data.targtype1_txt)
s1.set_xticklabels(s1.get_xticklabels(),rotation=90)
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### From this graph, we can see that Private Citizens & Property ,Police, Military, Government and Buisiness are the main target of Terrorist group

# %% [markdown]
# ## Let's see which type of weapon is most preferred by Terrosrists

# %%
plt.figure(figsize=(15,5))
s1=sns.countplot(data.weaptype1_txt.iloc[:40].sort_values(ascending=True))
s1.set_xticklabels(s1.get_xticklabels(),rotation=90)
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### From this, we can see that Explosives type weapons are most used and Incendiary

# %% [markdown]
# ### Terrorist Activities by Region in each Year

# %%
pd.crosstab(data.iyear, data.region_txt).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Year')
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# #### By analyzing this graph, from last decade we can see exponential growth of terrorist activities

# %% [markdown]
# ### Top Countries Affected

# %%
plt.figure(figsize=(15,6))
x=data['country_txt'].value_counts()[:15].index
y=data['country'].value_counts()[:15]
sns.barplot(x,y)
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### It appears that Iraq, Afghanistan and Pakistan are the most damaged countries during terrorist attacks

# %% [markdown]
# ### Let's check the Terrorist groups

# %%
data.gname.value_counts()[1:15]
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Kurdistan Workers' Party (PKK)                      2310
# Basque Fatherland and Freedom (ETA)                 2024
# Communist Party of India - Maoist (CPI-Maoist)      1878
# Maoists                                             1630
# Liberation Tigers of Tamil Eelam (LTTE)             1606
# Name: gname, dtype: int64

# %% [markdown]
# ##### Taliban,Islamic State of Iraq and the Levant (ISIL),Shining Path (SL) and Farabundo Marti National Liberation Front (FMLN) are the largest  and active Terrorist Groups

# %%
import folium
from folium.plugins import MarkerCluster 

filterYear = data['iyear'] == 1970
filterData = data[filterYear] 

reqFilterData = filterData.loc[:,'city':'longitude'] 
reqFilterData = reqFilterData.dropna() 

reqFilterDataList = reqFilterData.values.tolist()

map = folium.Map(location = [0, 30], tiles='CartoDB positron', zoom_start=1)
# clustered marker
markerCluster = folium.plugins.MarkerCluster().add_to(map)
for point in range(0, len(reqFilterDataList)):
    folium.Marker(location=[reqFilterDataList[point][1],reqFilterDataList[point][2]],
                  popup = reqFilterDataList[point][0]).add_to(markerCluster)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# # Conclusion:
# ###### Terrorist acts in the Middle East and northern Africa have been seen to have fatal consequences.
# ###### The Middle East and North Africa are seen to be the places of serious terrorist attacks.
# ###### In addition, look at the graphics, it appears that Iraq, Afghanistan and Pakistan are the most damaged countries during terrorist attacks.
#
# ### Thank You
